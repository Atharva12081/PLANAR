# %% [markdown]
# # PLANAR Pipeline Notebook
#
# Starter notebook to run the three parts of the PLANAR evaluation workflow.

# %%
# Run from PLANAR/
# !planar train-ae --config configs/default.yaml

# %%
# !planar cluster --config configs/default.yaml

# %%
# !planar train-transit --config configs/default.yaml

# %%
# !planar infer --config configs/default.yaml --data-dir data/raw
